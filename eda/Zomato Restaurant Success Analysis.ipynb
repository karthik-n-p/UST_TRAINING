# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
zomato_data= pd.read_csv('Downloads/zomato_restaurants.csv')

# %%
zomato_data.head(3)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
#
#                                              address             name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...            Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...   Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...  San Churro Cafe
#
#   online_order book_table   rate  votes                           phone  \
# 0          Yes        Yes  4.1/5    775  080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                    080 41714161
# 2          Yes         No  3.8/5    918                  +91 9663487993
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
#
# ...

# %%
zomato_data.shape
# Out:
# (51717, 17)

# %% [markdown]
# zomato_data.info()

# %%
# import plotly.offline as py

# %% [markdown]
# #### 1. Total number of restaurants

# %%
zomato_data['name'].unique()
# Out:
# array(['Jalsa', 'Spice Elephant', 'San Churro Cafe', ..., 'Nawabs Empire',
#        'SeeYa Restaurant',
#        'Plunge - Sheraton Grand Bengaluru Whitefield Hotel &...'],
#       dtype=object)

# %% [markdown]
# #### 2. Percentage with Online Order

# %%
percentage_yes = zomato_data[zomato_data['online_order']=='Yes']

# %%
percentage_yes_no=len(percentage_yes)

# %%
percentage2 =percentage_yes_no / zomato_data.shape[0] * 100
percentage2
# Out:
# 58.86652358025407

# %%
percentage_no = zomato_data[zomato_data['online_order']=='No']
percentage_no_no =len(percentage_no)
percentage1 =percentage_no_no / zomato_data.shape[0] * 100
percentage1
# Out:
# 41.133476419745925

# %%
sizes=[percentage1,percentage2]
plt.pie(sizes,labels=zomato_data['online_order'].value_counts().index,autopct="%0.2f")
# Out:
# ([<matplotlib.patches.Wedge at 0x22d38f09d60>,
# ...
#  [Text(0.30245810454915795, 1.0576006311422714, 'Yes'),
#   Text(-0.30245810454915834, -1.0576006311422714, 'No')],
#  [Text(0.16497714793590432, 0.576873071532148, '41.13'),
#   Text(-0.1649771479359045, -0.576873071532148, '58.87')])

# %%
zomato_data['online_order'].value_counts()/zomato_data.shape[0]*100
# Out:
# online_order
# Yes    58.866524
# No     41.133476
# Name: count, dtype: float64

# %% [markdown]
# #### 3. Restaurant with Online Booking

# %%
plt.pie(zomato_data['online_order'].value_counts()/zomato_data.shape[0]* 100,labels=zomato_data['online_order'].value_counts().index,autopct='%0.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x22d006d9fd0>,
# ...
#  [Text(-0.30245810454915784, 1.0576006311422714, 'Yes'),
#   Text(0.3024581045491579, -1.0576006311422714, 'No')],
#  [Text(-0.16497714793590426, 0.5768730715321481, '58.87'),
#   Text(0.1649771479359043, -0.576873071532148, '41.13')])

# %%
plt.pie(zomato_data['book_table'].value_counts()/zomato_data.shape[0]* 100,labels=zomato_data['book_table'].value_counts().index,autopct='%0.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x22d0074fa70>,
# ...
#  [Text(-1.0166665902958882, 0.41998695715001977, 'No'),
#   Text(1.0166666099568955, -0.41998690955642154, 'Yes')],
#  [Text(-0.5545454128886663, 0.22908379480910165, '87.53'),
#   Text(0.5545454236128521, -0.22908376884895715, '12.47')])

# %%
(zomato_data['book_table'].value_counts()/zomato_data.shape[0]).plot(kind='pie' ,autopct="%0.2f")
# Out:
# <Axes: ylabel='count'>

# %%
#### 4. Famous chains in banglore

# %%
b=zomato_data['rest_type'].value_counts().sort_values(ascending=False)[:20]

# %%
b.plot(kind='barh')
plt.xlabel('Names')
plt.ylabel('Resturant_count' )
sns.set_style('whitegrid')

# %% [markdown]
#  #### 4. find most popular restaurant types in banglore

# %%
rest_type=zomato_data['rest_type'].value_counts().sort_values(ascending =True)[:10]

rest_type
# Out:
# rest_type
# Quick Bites, Kiosk            1
# Sweet Shop, Dessert Parlor    1
# Food Court, Beverage Shop     2
# Pop Up                        2
# Bakery, Food Court            2
# Dessert Parlor, Food Court    2
# Dessert Parlor, Kiosk         2
# Cafe, Food Court              2
# Mess, Quick Bites             3
# Bhojanalya                    3
# Name: count, dtype: int64

# %%
sns.barplot(rest_type ,orient ='h',palette="Set1")
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_3532\3819205585.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(rest_type ,orient ='h',palette="Set1")
# <Axes: xlabel='count', ylabel='rest_type'>

# %% [markdown]
# #### 6. Distribution of Restaurant cost ( 2 person).

# %%
zomato_data['approx_cost(for two people)']=pd.to_numeric(zomato_data['approx_cost(for two people)'].replace(',','',regex=True))

# zomato_data['approx_cost(for two people)'].str.replace(',','')

# %%
import warnings

sns.distplot(zomato_data['approx_cost(for two people)'],color='red')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_3532\4070931579.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(zomato_data['approx_cost(for two people)'],color='red')
# <Axes: xlabel='approx_cost(for two people)', ylabel='Density'>

# %% [markdown]
# #### 7. least popular tye

# %%
rest_type
# Out:
# rest_type
# Quick Bites, Kiosk            1
# Sweet Shop, Dessert Parlor    1
# Food Court, Beverage Shop     2
# Pop Up                        2
# Bakery, Food Court            2
# Dessert Parlor, Food Court    2
# Dessert Parlor, Kiosk         2
# Cafe, Food Court              2
# Mess, Quick Bites             3
# Bhojanalya                    3
# Name: count, dtype: int64

# %%
rest_type=zomato_data['rest_type'].value_counts().sort_values(ascending =True)[:10]

# %%
rest_type.index
# Out:
# Index(['Quick Bites, Kiosk', 'Sweet Shop, Dessert Parlor',
#        'Food Court, Beverage Shop', 'Pop Up', 'Bakery, Food Court',
#        'Dessert Parlor, Food Court', 'Dessert Parlor, Kiosk',
#        'Cafe, Food Court', 'Mess, Quick Bites', 'Bhojanalya'],
#       dtype='object', name='rest_type')

# %%
least_rest_type=rest_type=zomato_data['rest_type'].value_counts().sort_values(ascending =True)[:10].index

# %%
least_rest_count=rest_type=zomato_data['rest_type'].value_counts().sort_values(ascending =True)[:10].values

# %%
b=[least_rest_type,least_rest_count]

# %%
sns.barplot(x = least_rest_count,y=least_rest_type,orient ='h',hue=least_rest_type,palette='Set1')
# Out:
# <Axes: ylabel='rest_type'>

# %%
plt.figure(figsize = (10,4))

# %%
sns.boxplot(zomato_data['approx_cost(for two people)'],color ='red' ,orient='h')
# Out:
# <Axes: xlabel='approx_cost(for two people)'>

# %%
Q1 = zomato_data['approx_cost(for two people)'].quantile(0.25)

# %%
Q2 = zomato_data['approx_cost(for two people)'].quantile(0.5)

# %%
Q3 = zomato_data['approx_cost(for two people)'].quantile(0.75)

# %%
IQR = Q3


- Q1
# Out:
# -300.0

# %%
print("inter quartile rang of cost for two people ", IQR)
# Out:
# inter quartile rang of cost for two people  650.0

# %% [markdown]
# * approx cost of two people range from 300 to 650  Yes the approx cost for two people is skewed towards positive hence positive skewness

# %%
#### Which are the top 20 loations whit most number of restaurants

# %%
zomato_data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
df=zomato_data['listed_in(city)'].value_counts().sort_values(ascending=False)[:20]

# %%
city=df.index
count=df.values

# %%
sns.barplot(x=count ,y=city ,orient='h',hue=city)
# Out:
# <Axes: ylabel='listed_in(city)'>

# %% [markdown]
# *most popular restaurant is BTM

# %%
#### 9. Most Popular food category

# %%
zomato_data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
dish=zomato_data['cuisines'].value_counts().sort_values(ascending=False)[:20].index

# %%
count=zomato_data['cuisines'].value_counts().sort_values(ascending=False)[:20].values

# %%
sns.barplot(x=count,y=dish,hue=dish,orient='h')
# Out:
# <Axes: ylabel='cuisines'>

# %% [markdown]
#     *Most eated food is north Indian ,chinese,southIndian ,biriyani outlets and least is beverage

# %% [markdown]
# #### 10. Distribution of Restaurant ratings.

# %%
sns.displot(zomato_data['rate'])

# %%
zomato_data['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', nan, '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
zomato_data['rate'] = zomato_data['rate'].str.replace('/5', '').replace('NEW', np.nan).replace('-', np.nan).astype('float64')

# %%
zomato_data['rate']
# Out:
# 0        4.1
# 1        4.1
# 2        3.8
# 3        3.7
# 4        3.8
#         ...
# 51712    3.6
# 51713    NaN
# 51714    NaN
# 51715    4.3
# 51716    3.4
# Name: rate, Length: 51717, dtype: float64

# %%
sns.distplot(zomato_data['rate'])

# %%
mo= zomato_data['rate'].mode()

# %% [markdown]
# #### 11. Top rated restaurant from most popular restaurant type

# %%
zomato_data
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
names=zomato_data['rest_type'].value_counts().sort_values(ascending=False)[:21].index

# %%
names
# Out:
# Index(['Quick Bites', 'Casual Dining', 'Cafe', 'Delivery', 'Dessert Parlor',
#        'Takeaway, Delivery', 'Casual Dining, Bar', 'Bakery', 'Beverage Shop',
#        'Bar', 'Food Court', 'Sweet Shop', 'Bar, Casual Dining', 'Lounge',
#        'Pub', 'Fine Dining', 'Casual Dining, Cafe',
#        'Beverage Shop, Quick Bites', 'Bakery, Quick Bites', 'Mess',
#        'Pub, Casual Dining'],
#       dtype='object', name='rest_type')

# %%
filtered_data = zomato_data[zomato_data['rest_type'].isin(names)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 filtered_data = zomato_data[zomato_data['rest_type'].isin(names)].sort_values(ascending=False)
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
ratings = filtered_data[['name','rate']]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 ratings.sort_values(ascending=False)
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %% [markdown]
# #### 12 Relationship between rating and approx cost for two person

# %%
sns.scatterplot(x='rate' ,y ='approx_cost(for two people)', data= zomato_data, hue='rate', palette='Set1')
# Out:
# <Axes: xlabel='rate', ylabel='approx_cost(for two people)'>

# %%
#### 13. Highlight the Restaurant frequency on Map

# %%
# !pip install geopy #converting name into latitude and longitude
# Out:
# ...
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/125.4 kB ? eta -:--:--
#    ------------ -------------------------- 41.0/125.4 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 125.4/125.4 kB 1.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#    ---------------------------------------- 40.3/40.3 kB ? eta 0:00:00
# ...

# %%
# !pip install folium 

#for creating map
# Out:
# ...
#    ---------------------------------------- 0.0/108.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/108.4 kB ? eta -:--:--
#    ----------- --------------------------- 30.7/108.4 kB 660.6 kB/s eta 0:00:01
#    ---------------------------------------- 108.4/108.4 kB 1.3 MB/s eta 0:00:00
# ...

# %%
from geopy.geocoders import Nominatim
locations=pd.DataFrame({"Name":zomato_data['location'].unique()})
locations['Name'] = locations['Name'].apply(lambda x: "Banglore" + str(x))
geolocator = Nominatim(user_agent="app")
lat_long =[]
for location in locations['Name']:
    location =geolocator.geocode(location)
    if location is None:
        lat_long.append(np.nan)
    else:
        geo=(location.latitude,location.longitude)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\urllib3\connection.py:464, in HTTPConnection.getresponse(self)
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# ...
