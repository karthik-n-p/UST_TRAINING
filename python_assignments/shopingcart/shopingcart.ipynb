# %%
class Product:
    def __init__(self,product_id,name,category,price):
        self.product_id = product_id
        self.name = name
        self.category = category
    
        self.price = price

    def __str__(self):
        return f'Expense id is {self.expense_id} \n date of expense is {self.date} \n Category is {self.category} \n Description is {self.description} \n Amount of expenditrue {self.amount}'
    


class UserFunctions:

    def __init__(self):
        self.cart = list()

    def add_cart(self,product):
        print(product)
       
        self.cart.append(product)
        print("Product added")
    
    
    
    def delete_cart(self,product_id):
        for i in range(len(self.cart)):
            if self.cart[i]['product_id'] == product_id:
                self.cart.remove(self.cart[i])
                print("Product delted successfully! ")
                return
        print("No item found with expense id")
        
    

    def display_cart(self):
        for i in range(len(self.cart)):
            print(f"Product {i} : \t {self.cart[i]}")
        if len(self.cart) == 0:
            print("No Items Found")
    
    



class AdminFunctions:

    def __init__(self):

        self.item_storage = list()

  
    def add_item(self,product):
        item = vars(product)
        self.item_storage.append(item)
        print("Product added")
    
    def update_item(self,product_id,new_product):
        d=vars(new_product)
        for i in range(len(self.item_storage)):
            print(self.item_storage[i])
            print(self.item_storage[i]['product_id'])
            if self.item_storage[i]['product_id'] == product_id:
                self.item_storage[i] = d
                print("Expense updated successfully ")
                return
        print("NO iterm found with expense id")
    
    def delete_item(self,product_id):
        for i in range(len(self.item_storage)):
            if self.item_storage[i]['product_id'] == product_id:
                self.item_storage.remove(self.item_storage[i])
                print("Product delted successfully! ")
                return
        print("No item found with expense id")
        
    

    def display_item(self):
        for i in range(len(self.item_storage)):
            print(f"Product {i+1} \t is {self.item_storage[i]}")
        if len(self.item_storage) == 0:
            print("No Items Found")
    
    def return_catalog(self):
        return self.item_storage
    
    






    

class Aunthetication:
    user_db={"user":"user","user1":"user1"}
    admin_db={"admin":"admin"}

    def user_login(self,username,password):
     
        if username in self.user_db:
            if self.user_db[username] == password:
                print("\nLogin Successful \n Welcome user {username} \n")
                usercli()
                
            else:
                print("\n Wrong Password \n")
        else:
            print('\n Wrong username')
    def admin_login(self,username,password):
            if username in self.admin_db:
                if self.admin_db[username] == password:
                    print("\n Welcome Admin {username} \n")
                    admincli()
                
                else:
                    print("\n Wrong Password \n")
            else:
                print('\n Wrong username')


import random
def generate_session_id():
    return random.randint(10000,100000)





        

f = AdminFunctions()
def admincli():
    session_id =generate_session_id()
    print(f"Admin session id is {session_id}")


   
    while True:
        choice=input("Select a Choice \n 1. Add item \n 2. Update \n 3 . Delete \n 4. Display Catalog \n 6. Log Out \n ")
        if choice == '1':
            print("\n Enter the details of item \n")
            product_id = int(input("Enter unique id for expense : "))
            name = input("Enter the name of the product ")
            category = input("Enter the category : ")
            Price = int(input("Enter the amount of expenditure"))

            obj1=Product(product_id,name,category,Price)
           
            f.add_item(obj1)
        elif choice == '2':
            print("\n Enter the details of the updated expense \n")
            product_id = int(input("Enter unique id of item to be updated : "))
            new_product_id =int(input("Enter the new unique id of item : "))
            name = input("Enter the name : ")
            category = input("Enter the Category : ")
            
            amount = int(input("Enter the amount of expenditure"))

            obj2=Product(new_product_id,name,category,amount)
            f.update_item(product_id,obj2)

        elif choice == '3':
            print("\n Enter the expense id for deleting Expense : ")
            e_id = int(input("Enter the expense id for deleting Expense : "))
            f.delete_item(e_id)

        elif choice == '4':
            print('\n Current Catalog is \n')
            f.display_item()
        
      
        
        elif choice == '6':
            print("\n Thank you for using our service Loging Out! \n")
            break

        else:
            print("\n Wrong Choice \n")



def usercli():
    session_id =generate_session_id()
    print(f"User session id is {session_id}")

    f1 = UserFunctions()
   
    
   
    while True:
        choice=input("Select a Choice \n 1. Add to cart  \n 2 . Delete from cart \n 3. Display Cart \n4. Display Catalog \n5.Check Out \n 6.Log out  \n ")
        if choice == '1':
            print("\n Select The item to be added \n")
            cart1=f.return_catalog()
            for i in range(len(cart)):
                print(f"Product {i} \t {cart[i]}")
            p=int(input("Select the item number "))

            item1=cart1[p]

            f1.add_cart(item1)
        elif choice == '2':
            f1.display_cart()
            print("\n Enter the item id for deleting item : ")
            e_id = int(input("Enter the product id to be delted from cart : "))
           
            f1.delete_cart(e_id)
        
        elif choice == '3':
            print("\nThe current cart is  \n")
            f1.display_cart()
        
        elif choice == '4':
            print("\n The availiable products  are \n")
            cart=f.return_catalog()
            for i in range(len(cart)):
                print(f"Product {i} \t {cart[i]}")
        
        elif choice == '5':
            
            payment_method = input("Enter the payment method : \n Debit \n Credit \n ")
            print(f"\n{payment_method} payment successful \n Redirecting ....")

        elif choice == '6':
            print("Loggin out ...")
            break
            

        





            




            
            

     
        
      
        
        elif choice == '6':
            print("\n Thank you for using our service ! \n")
            break

        else:
            print("\n Wrong Choice \n")
        







def main():
    print("\n Welcome to Demo marketplace \n")
    while True:
        choice =input("1. Login 2. Exit ")
        if choice == '1':

            print("\n User Authentication \n")
            user_type = int(input("choose \n 1 for user \n 2 for admin \n")) 
            name = input("Enter the user name : ")
            password =input("Enter the password : ")
            u = Aunthetication()
            if user_type == 1:
                u.user_login(name,password)
            elif user_type == 2:
                u.admin_login(name,password)
        else:
            break
    
if __name__ == "__main__":
    main()
